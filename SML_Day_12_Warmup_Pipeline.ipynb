# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/ML_DSAI/blob/main/SML_Day_12_Warmup_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SML-Day12_Warmup_Pipeline

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.tree import DecisionTreeRegressor

from sklearn import set_config
set_config(transform_output='pandas')

# Load dataset and sample it so our grid search runs quickly in class!
df = sns.load_dataset('diamonds').sample(5000, random_state=42)

# Separate features and target
X = df.drop(columns=['price'])
y = df['price']

# %% [markdown]
# ## Exercise 1: Train/Test Split
# Split X and y into training and testing sets. Use a 20% test size and a `random state= 42`

# %%
# your code here
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, ramdomstate=42 )

# %% [markdown]
# ## Exercise 2: Build the Preprocessor(Use Pipeline instead of make_pipeline)
#
# Create a ColumnTransformer that handles numeric, ordinal, and nominal features.
#
# * Numeric: carat, depth, table, x, y, z (Impute median, StandardScaler)
#
# * Ordinal: clarity (Impute `most frequent`, OrdinalEncoder `handle_unknown='use_encoded_value', unknown_value=-1`) Order: I1, SI2, SI1, VS2, VS1, VVS2, VVS1, IF
#
# * Nominal: cut, color (Impute `most frequent`, OneHotEncoder dropping the first column)

# %%
# your code here

# %% [markdown]
# ## Exercise 3: The Overfitting Trap
# Create a pipeline combining your preprocessor and a `DecisionTreeRegressor(random_state=42)`. Use `cross_validate` to check both the train and test R-squared scores.

# %%
# your code here

# %% [markdown]
# ## Exercise 4: Create a Parameter Grid to fix the Overfitting
# Create a parameter grid to constrain the Decision Tree. Try limiting the `max_depth` and increasing the `min_samples_split`.

# %%
# your code here

# %% [markdown]
# ## Exercise 5: Grid Search & The Cure
# Run a `GridSearchCV` with 10 folds using your parameter grid. Print out the best parameters, and check the new train and test scores of the winning model. Did we close the gap?
#
# Hint: use the attribute `.best_index` to extract retrieve the train and test scores

# %%
# your code here

# %% [markdown]
# ## Exercise 6: Final Prediction
#
# Calculate the Root Mean Squared Error (RMSE) and Mean Absolute Percentage Error(MAPE) on the test set to see how far off our tuned model's predictions are in actual dollars.

# %%
# your code here
