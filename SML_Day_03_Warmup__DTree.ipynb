# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/ML_DSAI/blob/main/SML_Day_03_Warmup__DTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://drive.google.com/file/d/1g3uhw_y3tboRm2eYDPfUzXXsw8IOYDCy/view?usp=sharing"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]

to_drop = ['PassengerId', 'Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
data = pd.read_csv(path).drop(columns=to_drop)

# %% [markdown]
# ####Exercise 1: Pop out the `'Survived'` column from the rest of the data and store it in a variable called `y`. Store the other features in a variable called `X`

# %%
X = data.copy()
y = X.pop('Survived')

# %% [markdown]
# #####Hint:

# %% [markdown]
# ```
# y = _________.pop('Survived')
# ```

# %% [markdown]
# ####Exercise 2: Perform a train-test split, setting aside 20% of the data for testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2, random_state=12345)

# %% [markdown]
# #####Hint:

# %% [markdown]
# Find the documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
# ```
# from sklearn.____________ import ________________
# X_train, X_test, y_train, y_test = train_test_split(________________)
# ```

# %% [markdown]
# ####Exercise 3: Import the `SimpleImputer` and initialize it with the `strategy` `'median'`

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='median')
# Out:
# SimpleImputer(strategy='median')

# %% [markdown]
# #####Hint:

# %% [markdown]
# Find the documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html)
# ```
# from sklearn.________ import _______________
# imputer = SimpleImputer(_____=_____)
# ```

# %% [markdown]
# ####Exercise 4: Fit the imputer to the training data and then use it to fill the missing values in both the training and testing data

# %%
imputer.fit(X)
X_test = imputer.transform(X_test)
X_train = imputer.transform(X_train)

# %% [markdown]
# #####Hint:

# %% [markdown]
# `imputer.fit()`<br>
# `imputer.transform()`

# %% [markdown]
# ####Exercise 5: Import and initialize the `DecisionTreeClassifier` and fit it to the training data. Then predict the labels for the testing data

# %%
from sklearn.tree import DecisionTreeClassifier
mytree = DecisionTreeClassifier(X_train, max_depth = 5)
mytree.fit(X_train,y_train)
test_pedict

# %% [markdown]
# #####Hint:

# %% [markdown]
# Find the documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
# ```
# from sklearn._______ import DecisionTreeClassifier
# model = ________________()
# model.fit(_____, _____)
# test_pred = model._______(X_test)
# ```

# %% [markdown]
# ####Exercise 6: Score the testing accuracy of the decision tree

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Find the documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
# ```
# from sklearn._______ import accuracy_score
# accuracy_score(_______, _______)
# ```

# %% [markdown]
# #### Bonus I: Plot the tree

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Use plot_tree [see documentation](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html)

# %% [markdown]
# #### Bonus II: What are the most important features?

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Check the documentation to find the right method...
#
#
#
# ```
# feature_names = ??
#
# feat_importances = pd.Series(decision_tree.??, index=feature_names)
# print(feat_importances)
#
# feat_importances
# ```
