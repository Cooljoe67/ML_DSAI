# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/ML_DSAI/blob/main/UML_Day_7_Warmup__Agglomerative.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import set_config
set_config(transform_output="pandas")

url = "https://drive.google.com/uc?export=download&id=1oYQSNxfvw6kFr6-N9rKLRAnLXlp0osEt"
songs_df = pd.read_csv(url)
songs_df.columns = songs_df.columns.str.strip()
songs_df = songs_df.drop(columns=['Unnamed: 0','mode','duration_ms','time_signature','id', 'html', 'key', 'type'])

songs_df = songs_df.set_index(["name", "artist"])

# %% [markdown]
# #### Exercise 1: Scale the Data

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn" + the scaler you want to try to find the documentation so you can see where to import it from
# ```
# from sklearn._____________ import _____________
# scaler = _____________()
# scaled_data = scaler.____________(data)
# ```

# %% [markdown]
# #### Exercise 2: Use PCA to reduce the scaled data's dimensionality, keeping at least 99% of the variance

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn PCA" to find the documentation so you can see where to import it from
# ```
# from sklearn.____________ import PCA
# _______ = ____(____________=___)
# denoised_data = _______.fit_transform(data)
# ```

# %% [markdown]
# #### Exercise 3: Cluster the data with Agglomerative Clustering

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn agglomerative clustering" to find the documentation so you can see where to import it from
# ```
# from sklearn._________ import AgglomerativeClustering
# model = _________(________=_)
# model.fit(denoised_data)
# ```

# %% [markdown]
# #### Exercise 4: Add the cluster labels to the data frame and sort it to see the different clusters

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# `foods_df['cluster'] = model.________`<br>
# Check [the attributes section of the KMeans documentation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#:~:text=for%20more%20details.-,Attributes,-%3A) to see where you can get the model's labels<br><br>
# `df.sort_values()`

# %% [markdown]
# #### Exercise 5: Try out different numbers of clusters. Also consider trying different linkage criteria or metrics (consider `metric='cosine'` for a more significant change in behavior)

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Check out the documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html)

# %% [markdown]
# #### BONUS: See if you can plot the dendrogram! You can find code for this in the documentation. Copy, paste, and alter it to plot your own!

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# [This](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#:~:text=For%20an%20example%20of%20dendrogram%20visualization%2C%20see%20Plot%20Hierarchical%20Clustering%20Dendrogram.) is where it is mentioned in the documentation. They link to an example and you can copy the code from it, just make sure you swap in your own model and data
