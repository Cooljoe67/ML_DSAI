# %% [markdown]
# <a href="https://colab.research.google.com/github/Cooljoe67/ML_DSAI/blob/main/UML_Day_6_Warmup__DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import set_config
set_config(transform_output="pandas")

url = "https://drive.google.com/uc?export=download&id=1oYQSNxfvw6kFr6-N9rKLRAnLXlp0osEt"
songs_df = pd.read_csv(url)
songs_df.columns = songs_df.columns.str.strip()
songs_df = songs_df.drop(columns=['Unnamed: 0','mode','duration_ms','time_signature','id', 'html', 'key', 'type'])

songs_df = songs_df.set_index(["name", "artist"])

# %% [markdown]
# #### Exercise 1: Scale the Data

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn" + the scaler you want to try to find the documentation so you can see where to import it from
# ```
# from sklearn._____________ import _____________
# scaler = _____________()
# scaled_data = scaler.____________(data)
# ```

# %% [markdown]
# #### Exercise 2: Use PCA to reduce the scaled data's dimensionality, keeping the top 5 components

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn PCA" to find the documentation so you can see where to import it from
# ```
# from sklearn.____________ import PCA
# _______ = ____(____________=5)
# denoised_data = _______.fit_transform(data)
# ```

# %% [markdown]
# #### Exercise 3: Cluster the data with DBSCAN

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# Google "sklearn DBSCAN" to find the documentation so you can see where to import it from
# ```
# from sklearn._________ import DBSCAN
# model = _________(___=____)
# model.fit(denoised_data)
# ```

# %% [markdown]
# #### Exercise 4: Add the cluster labels to the data frame and sort it to see the different clusters

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# `foods_df['cluster'] = model.________`<br>
# Check [the attributes section of the KMeans documentation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#:~:text=for%20more%20details.-,Attributes,-%3A) to see where you can get the model's labels<br><br>
# `df.sort_values()`

# %% [markdown]
# #### Exercise 5: Try out different values for DBSCAN's most important hyperparameter (see hint if you don't know what it is)

# %%
# Your code here

# %% [markdown]
# ##### Hint:

# %% [markdown]
# The most important hyperparameter for DBSCAN is epsilon. You can look at [the documentation](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#:~:text=epsfloat%2C%20default,and%20distance%20function.) to see how to adjust it

# %% [markdown]
# #### Bonus: Use a k-distance graph to find a good eps

# %%
# Your code here

# %% [markdown]
# #### Hint:

# %% [markdown]
# Code from LMS:
# ```
# from sklearn.neighbors import NearestNeighbors
# import seaborn as sns
#
# # Compute the nearest neighbours
# neighbours = NearestNeighbors(n_neighbors=3)
# neighbours.fit(X_scaled)
# distances, indices = neighbours.kneighbors(X_scaled)
#
# # Extract the distances to the 3rd nearest neighbour
# third_distances = distances[:, 2]
#
# # Sort the distances
# sorted_distances = sorted(third_distances)
#
# # Plot using Seaborn
# (
#     sns.relplot(kind="line",
#                 x=range(len(sorted_distances)),
#                 y=sorted_distances)
#     .set_axis_labels("Data Points sorted by distance",
#                      "3rd Nearest Neighbour Distance")
#     .set(title="k-distance Graph")
# )
# ```
